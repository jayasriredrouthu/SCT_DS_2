# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset
df = pd.read_csv(r"C:\task2\titanic_cleaned.csv")

# Display first 5 rows
print(df.head())

# Dataset Information
print(df.info())

# Statistical Summary
print(df.describe())
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#   Embarked  Sex_Encoded  Embarked_Encoded  FamilySize  IsAlone     AgeGroup  \
# 0        S            0                 0           2        0  Young Adult
# 1        C            1                 1           2        0        Adult
# 2        S            1                 0           1        1  Young Adult
# 3        S            1                 0           2        0  Young Adult
# 4        S            0                 0           1        1  Young Adult
#
#   FareBand
# 0      Low
# 1     High
# 2      Low
# 3     High
# 4      Low
# ...

# %%
# Check missing values
print(df.isnull().sum())

# Remove missing values
df = df.dropna()

# Remove duplicate rows
df = df.drop_duplicates()

# Final dataset shape
print("Dataset Shape:", df.shape)
# Out:
# PassengerId         0
# Survived            0
# Pclass              0
# Sex                 0
# Age                 0
# SibSp               0
# Parch               0
# Fare                0
# Embarked            0
# Sex_Encoded         0
# Embarked_Encoded    0
# FamilySize          0
# IsAlone             0
# AgeGroup            0
# FareBand            0
# dtype: int64
# Dataset Shape: (891, 15)

# %%
plt.figure(figsize=(6,5))

sns.countplot(data=df, x="Survived", hue="Survived", palette="Set2", legend=False)

plt.title("Survival Count")
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Number of Passengers")

plt.show()

# %%
plt.figure(figsize=(6,5))

sns.countplot(data=df, x="Sex", hue="Survived", palette="Set1")

plt.title("Survival by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Age"], bins=20, color="skyblue", edgecolor="black")

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Heatmap")

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.boxplot(
    data=df[["Age","Fare"]],
    palette="Set3"
)

plt.title("Boxplot for Outlier Detection")

plt.show()

# %%
sns.pairplot(
    df,
    vars=["Age","Fare","Pclass"],
    hue="Survived",
    palette="Set2"
)

plt.show()

# %%
plt.figure(figsize=(7,5))

sns.barplot(
    data=df,
    x="Pclass",
    y="Survived",
    palette="Blues"
)

plt.title("Average Survival Rate by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Average Survival Rate")

plt.show()
# Out:
# C:\Users\jayas\AppData\Local\Temp\ipykernel_2440\1825077032.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
print("="*50)
print("Exploratory Data Analysis Completed")
print("="*50)

print("\nKey Observations:")

print("1. Female passengers had a higher survival rate than males.")

print("2. First-class passengers survived more frequently than second and third class passengers.")

print("3. Most passengers were young adults.")

print("4. Fare distribution is highly right-skewed.")

print("5. Boxplots indicate the presence of outliers in Fare and Age.")

print("6. Correlation heatmap shows relationships among numerical variables.")
# Out:
# ...
# Exploratory Data Analysis Completed
# ...
#
# Key Observations:
# 1. Female passengers had a higher survival rate than males.
# 2. First-class passengers survived more frequently than second and third class passengers.
# 3. Most passengers were young adults.
# 4. Fare distribution is highly right-skewed.
# 5. Boxplots indicate the presence of outliers in Fare and Age.
# 6. Correlation heatmap shows relationships among numerical variables.
